# %% [markdown]
# <a href="https://colab.research.google.com/github/yeju321qaz/assignment/blob/main/0404assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install paho-mqtt

# %%
import json
import requests
n=0

def doit(topic, payload):
  global n
  print(topic, payload)
  j=json.loads(payload)
  #print(j['co2'])
  #url='https://api.thingspeak.com/update?api_key=MBXHFKNOS3NTXOGA'
  url='https://api.thingspeak.com/update?api_key=JFW8YKZFCGKO47W1&field1=0'
  url +='&field1='+j['co2']
  url +='&field2='+j['bme680'].split(',')[0]
  if n>15:
    r=requests.get(url)
    print(url, r.text)
    n=0
  n+=1

# %%
import paho.mqtt.client as mqtt

def on_connect(client, userdata, flags, reason_code, properties):
    print(f"Connected with result code {reason_code}")
    client.subscribe("connectware/indoor/data/1501")

def on_message(client, userdata, msg):
    doit(msg.topic, msg.payload.decode('utf8'))

client = mqtt.Client(mqtt.CallbackAPIVersion.VERSION2)
client.on_connect = on_connect
client.on_message = on_message

client.connect("damoa.io", 1883, 60)
client.loop_forever()
# Out:
# Connected with result code Success
# connectware/indoor/data/1501 {"dust":"31,35","co2":"418","bme680":"29.25,25.53,1473165,100887,36.45","time":"2024-04-05 15:59:00", "serial":88396, "ip":"203.255.190.49"}
# connectware/indoor/data/1501 {"dust":"30,34","co2":"418","bme680":"29.24,25.50,1476399,100887,36.45","time":"2024-04-05 15:59:01", "serial":88397, "ip":"203.255.190.49"}
# connectware/indoor/data/1501 {"dust":"29,31","co2":"418","bme680":"29.24,25.48,1482910,100887,36.53","time":"2024-04-05 15:59:02", "serial":88398, "ip":"203.255.190.49"}
# connectware/indoor/data/1501 {"dust":"30,32","co2":"418","bme680":"29.24,25.48,1478022,100887,36.45","time":"2024-04-05 15:59:03", "serial":88399, "ip":"203.255.190.49"}
# connectware/indoor/data/1501 {"dust":"31,34","co2":"418","bme680":"29.24,25.46,1474780,100888,36.45","time":"2024-04-05 15:59:04", "serial":88400, "ip":"203.255.190.49"}
# ...
