# %% [markdown]
# <a href="https://colab.research.google.com/github/yeju321qaz/assignment/blob/main/0404assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install paho-mqtt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.9/66.9 kB 1.3 MB/s eta 0:00:00
# ...

# %%
import paho.mqtt.client as mqtt

def on_connect(client, userdata, flags, reason_code, properties):
    print(f"Connected with result code {reason_code}")
    client.subscribe("connectware/indoor/data/#")

def on_message(client, userdata, msg):
    print(msg.topic, msg.payload.decode('utf8'))

client = mqtt.Client(mqtt.CallbackAPIVersion.VERSION2)
client.on_connect = on_connect
client.on_message = on_message

client.connect("damoa.io", 1883, 60)
client.loop_forever()
# Out:
# Connected with result code Success
# connectware/indoor/data/1502 {"dust":"29,32","co2":"463","bme680":"30.39,24.44,2476722,100937,32.35","time":"2024-04-05 15:47:11", "serial":83132, "ip":"203.255.190.49"}
# connectware/indoor/data/1503 {"dust":"26,28","co2":"382","bme680":"29.67,26.07,900473,100894,35.95","time":"2024-04-05 15:47:11", "serial":83135, "ip":"203.255.190.49"}
# connectware/indoor/data/1501 {"dust":"30,32","co2":"424","bme680":"29.02,26.75,1322517,100887,36.53","time":"2024-04-05 15:47:11", "serial":87687, "ip":"203.255.190.49"}
# connectware/indoor/data/1502 {"dust":"31,33","co2":"463","bme680":"30.39,24.44,2479030,100937,32.35","time":"2024-04-05 15:47:12", "serial":83133, "ip":"203.255.190.49"}
# connectware/indoor/data/1503 {"dust":"25,27","co2":"382","bme680":"29.67,26.06,892617,100894,35.95","time":"2024-04-05 15:47:12", "serial":83136, "ip":"203.255.190.49"}
# ...
